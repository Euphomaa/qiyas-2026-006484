# %%
data=[1,2,3,4,5,6,7,8]
result=[value**2 + value/2 for value in data]
print(result)
# Out:
# [1.5, 5.0, 10.5, 18.0, 27.5, 39.0, 52.5, 68.0]

# %%
range_value = range(0,15)
res=[value for value in range_value if value %2 ==0]
print(res)
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14]

# %%
c=[1,2,3,4,5,6]
even=filter(lambda x:x%2==0, c)
print(list(even))
# Out:
# [2, 4, 6]

# %%
check=lambda x:"positive" if x>0 else "Negative" if x<0 else"Zero"
print(check(5))
print(check(-3))
print(check(0))
# Out:
# positive
# Negative
# Zero

# %%
# !git init
# !git add ex2.ipynb
